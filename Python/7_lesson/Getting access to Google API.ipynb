# %%
# !pip3 install gspread
# Out:
# Collecting gspread
#   Using cached gspread-5.3.2-py3-none-any.whl (34 kB)
# Requirement already satisfied: google-auth>=1.12.0 in /opt/anaconda3/lib/python3.8/site-packages (from gspread) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from gspread) (0.4.5)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth>=1.12.0->gspread) (4.2.2)
# Requirement already satisfied: setuptools>=40.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth>=1.12.0->gspread) (52.0.0.post20210125)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied: requests>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.25.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.26.4)
# Installing collected packages: gspread
# Successfully installed gspread-5.3.2

# %%
# !pip3 install oauth2client
# Out:
# Collecting oauth2client
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: six>=1.6.1 in /opt/anaconda3/lib/python3.8/site-packages (from oauth2client) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /opt/anaconda3/lib/python3.8/site-packages (from oauth2client) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /opt/anaconda3/lib/python3.8/site-packages (from oauth2client) (0.4.8)
# Collecting httplib2>=0.9.1
#   Using cached httplib2-0.20.4-py3-none-any.whl (96 kB)
# Requirement already satisfied: rsa>=3.1.4 in /opt/anaconda3/lib/python3.8/site-packages (from oauth2client) (4.7.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/anaconda3/lib/python3.8/site-packages (from httplib2>=0.9.1->oauth2client) (2.4.7)
# Installing collected packages: httplib2, oauth2client
# Successfully installed httplib2-0.20.4 oauth2client-4.1.3

# %%
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials


# Specify path to your file with credentials
path_to_credential = 'karpovcourses-v1-5328e2197a70.json' 

# Specify name of table in google sheets
table_name = 'Бот Зорич/Кострикин'

scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = ServiceAccountCredentials.from_json_keyfile_name(path_to_credential, scope)

gs = gspread.authorize(credentials)
work_sheet = gs.open(table_name)

# Select 1st sheet
sheet1 = work_sheet.sheet1

# Get data in python lists format
data = sheet1.get_all_values()

# Get header from data
headers = data.pop(0)

# Create df
df = pd.DataFrame(data, columns=headers)
df
# Out:
#                                    Дедлайн: 18.10.20              не сделал  \
# 0                                                   №       Emil      Aldar
# 1   Глава 1 Некоторые общематематические понятия и...
# 2                            § 1 Логическая символика
# 3                                                   1     сделал     сделал
# 4                                                   2     сделал     сделал
# ..                                                ...        ...        ...
# 72                                                  4  не сделал  не сделал
# 73                                                  5  не сделал  не сделал
# 74                                                  6  не сделал  не сделал
# 75                                                  7  не сделал  не сделал
# 76                                                  8  не сделал  не сделал
#
#        сделал  рассказал                                                 \
# 0      Саша П    Милан М  Rishat S.     Рома Е   Poincare  Konstantin B
# 1
# 2
# 3   не сделал     сделал     сделал     сделал     сделал        сделал
# 4   не сделал     сделал     сделал     сделал     сделал        сделал
# ..        ...        ...        ...        ...        ...           ...
# 72  не сделал  не сделал  не сделал  не сделал  не сделал     не сделал
# 73  не сделал  не сделал  не сделал  не сделал  не сделал     не сделал
# 74  не сделал  не сделал  не сделал  не сделал  не сделал     не сделал
# 75  не сделал  не сделал  не сделал  не сделал  не сделал     не сделал
# 76  не сделал  не сделал  не сделал  не сделал  не сделал     не сделал
#
#                ...                                                         \
# 0    Dmitry E  ...
# 1              ...
# 2              ...
# 3   не сделал  ...  не сделал  не сделал  не сделал  не сделал  не сделал
# 4   не сделал  ...  не сделал  не сделал  не сделал  не сделал  не сделал
# ..        ...  ...        ...        ...        ...        ...        ...
# 72  не сделал  ...  не сделал  не сделал  не сделал  не сделал  не сделал
# 73  не сделал  ...  не сделал  не сделал  не сделал  не сделал  не сделал
# 74  не сделал  ...  не сделал  не сделал  не сделал  не сделал  не сделал
# 75  не сделал  ...  не сделал  не сделал  не сделал  не сделал  не сделал
# 76  не сделал  ...  не сделал  не сделал  не сделал  не сделал  не сделал
#
#
# 0
# 1
# 2
# 3   не сделал  не сделал  не сделал  не сделал  не сделал
# 4   не сделал  не сделал  не сделал  не сделал  не сделал
# ..        ...        ...        ...        ...        ...
# 72  не сделал  не сделал  не сделал  не сделал  не сделал
# 73  не сделал  не сделал  не сделал  не сделал  не сделал
# 74  не сделал  не сделал  не сделал  не сделал  не сделал
# 75  не сделал  не сделал  не сделал  не сделал  не сделал
# 76  не сделал  не сделал  не сделал  не сделал  не сделал
#
# [77 rows x 26 columns]
